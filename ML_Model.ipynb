# %% [markdown]
# <a href="https://colab.research.google.com/github/0007anuragsharma/Python-logical/blob/main/ML_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ML Models

# Data Creating ---> data cleaning and preprocessing ---> select ML model based on target data--->
#model training ----> model prediction ---> Evaluation the model


# types od ML models
#(1) Supervised ML model ----> In this we will provide values with label
#(2) Unsupervised ML model --> in THIS We will provied only values not columns name

# %%
# 1. supervised ml model

# types of data
# 1. Continous --> LinearRegression , DecisionTreeRegressor ,RandomForestRegressor
# 2.Discrete--> LogisticRegression ,D.T.Classifier,R.F.Classifier,NaiveBayes,Svm

# %% [markdown]
# Linear Regression

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/insurance.csv")
df.head(2)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['sex'] = lb.fit_transform(df['sex'])
df['smoker'] = lb.fit_transform(df['smoker'])
df['region'] = lb.fit_transform(df['region'])

# %%
df.head(2)
# Out:
#    age  sex    bmi  children  smoker  region     charges
# 0   19    0  27.90         0       1       3  16884.9240
# 1   18    1  33.77         1       0       2   1725.5523

# %%
x = df.drop(columns = ['charges'])
y = df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train, y_test = train_test_split(x,y, test_size = 0.2,random_state= 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7833463107364539

# %%
df = pd.read_csv("/content/tips.csv")
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['sex'] = lb.fit_transform(df['sex'])
df['smoker'] = lb.fit_transform(df['smoker'])
df['day'] = lb.fit_transform(df['day'])
df['time'] = lb.fit_transform(df['time'])

# %%
df.head(2)
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3

# %%
x = df.drop(columns = ['total_bill'])
y = df['total_bill']

# %%
from sklearn.model_selection import  train_test_split

# %%
x_train, x_test , y_train,y_test = train_test_split(x,y, test_size = 0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6334779105328128

# %%
df = pd.read_csv("/content/Salary_Data.csv")
df.head(2)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205

# %%
import plotly.express as px

# %%
import plotly.graph_objects as go

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
figure = px.scatter(data_frame= df,
                    x = 'Salary',
                    y = 'YearsExperience',
                    size = 'YearsExperience',
                    trendline = 'ols')

# %%
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
x = np.asanyarray(df[['YearsExperience']])
y = np.asanyarray(df[['Salary']])

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size= 0.2, random_state = 42)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
a = float(input("Years of Experience : "))
features = np.array([[a]])
print('Predicted Salary = ', lr.predict(features))
# Out:
# Years of Experience : 10
# Predicted Salary =  [[119559.73624209]]
