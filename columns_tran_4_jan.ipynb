# %% [markdown]
# <a href="https://colab.research.google.com/github/0007anuragsharma/Python-logical/blob/main/columns_tran_4_jan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv("/content/covid_toy.csv")
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(df.drop(columns =
        ['has_covid']), df['has_covid'],test_size = 0.2  )

# %%
x_train.shape
# Out:
# (80, 5)

# %%
# Manually Tyoe Output

#adding simple imputer to feaver columns
si = SimpleImputer(strategy = 'mean')
x_train_fever = si.fit_transform(x_train[['fever']])

#also the test data
x_test_fever = si.fit_transform(x_test[['fever']])

x_train_fever.shape
# Out:
# (80, 1)

# %%
# ordinal Encoding ---> cough

oe = OrdinalEncoder(categories= [['Mild','Strong']])
x_train_cough = oe.fit_transform(x_train[['cough']])

#also the test data
x_test_cough = oe.fit_transform(x_test[['cough']])

x_train_cough.shape
# Out:
# (80, 1)

# %%
# OneHot Encoder ---> Gender , city

ohe = OneHotEncoder(drop = 'first' ,sparse_output = False)
x_train_gender_city = ohe.fit_transform(x_train[['gender' , 'city']])

x_test_gender_city = ohe.fit_transform(x_test[['gender' ,'city']])
x_train_gender_city.shape
# Out:
# (80, 4)

# %%
# Extracting Age

x_train_age  =x_train.drop(columns = ['gender','fever','cough','city']).values

#also the test data
x_test_age = x_test.drop(columns =['gender','fever','cough','city']).values

# %%
x_train_age.shape
# Out:
# (80, 1)

# %%
x_train_transformed=np.concatenate((x_train_age,x_train_fever,
                                    x_train_gender_city,
                                    x_train_cough),axis=1)

# %%
x_train_transformed.shape
# Out:
# (80, 7)

# %%
###By the Help OF columns Transformer

# %%
from sklearn.compose import ColumnTransformer

transformer=ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer(),['fever']),
    ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tnf3',OneHotEncoder(sparse_output=False,drop="first"),['gender','city'])
],remainder='passthrough')
# remainder passthoryugh ==> it means rest alll columns remain same

# %%
transformer.fit_transform(x_train).shape
# Out:
# (80, 7)

# %%
transformer.transform(x_test).shape
# Out:
# (20, 7)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
transformer = ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer(),['fever']),
    ('tnf2',LabelEncoder(),['cough']),
    ('tnsf3',)
],remainder = 'passthrough')

# %%
transformer.fit_transform(x_train).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-e238d82a44f1> in <cell line: 0>()
# ----> 1 transformer.fit_transform(x_train).shape
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# ...

# %%
transformer
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('tnf1', SimpleImputer(), ['fever']),
#                                 ('tnf2', LabelEncoder(), ['cough']),
#                                 ('tnsf3',
#                                      age  fever   cough has_covid  gender_Male  city_Delhi  city_Kolkata  \
# 0    60  103.0    Mild        No         True       False          True
# 1    27  100.0    Mild       Yes         True        True         False
# 2    42  101.0    Mild        No         True        True         False
# 3    31   98.0    Mild        No        False       False          True
# 4    65  101.0    Mild        No        False       False         False
# ..  ...    ...     ...       ...          ...         ...           ...
# 95   12  104.0    Mild        No        False       False         False
# 96   51  101.0  Strong       Yes        False       False          True
# ...

# %%
transformer = ColumnTransformer(transformers=[
    ('tnf1', SimpleImputer(strategy='mean'), ['fever']),
    ('tnf2', OneHotEncoder(drop='first', handle_unknown='ignore'), ['gender', 'city'])
], remainder='passthrough')

# %%
transformed_data = transformer.fit_transform(x_train)

# %%
transformed_data.shape
# Out:
# (80, 7)

# %%
df = pd.read_csv("/content/insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
a = pd.get_dummies(df,columns = ['sex','smoker','region'],drop_first = True)
a = a.astype(int)

# %%
a
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes  region_northwest  \
# 0      19   27         0    16884         0           1                 0
# 1      18   33         1     1725         1           0                 0
# 2      28   33         3     4449         1           0                 0
# 3      33   22         0    21984         1           0                 1
# 4      32   28         0     3866         1           0                 1
# ...   ...  ...       ...      ...       ...         ...               ...
# 1333   50   30         3    10600         1           0                 1
# 1334   18   31         0     2205         0           0                 0
# 1335   18   36         0     1629         0           0                 0
# 1336   21   25         0     2007         0           0                 0
# 1337   61   29         0    29141         0           1                 1
#
#       region_southeast  region_southwest
# ...

# %%
ohe = OneHotEncoder()

# %%
ohe = OneHotEncoder(drop = 'first' ,sparse_output = False , dtype=np.int32)

# %%
df = ohe.fit_transform(df[['sex','region','smoker']])
