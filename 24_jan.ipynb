# %% [markdown]
# <a href="https://colab.research.google.com/github/0007anuragsharma/Python-logical/blob/main/24_jan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pandas ---> pandas is an opern sourse library that is used for handle data manipulation

# %%
# Data structure of pandas --->
# 1) Series---> It is one dimensional array is show only values not columns name.
# 2) DataFrame ---> it is multi-dimensional array it show values with columns name

# %%
import pandas as pd

# %%
# 1) Series

a = pd.Series([1,2,3,4,5])
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
# DataFrame

a = {
    "ID":[1,2,3,4],
    "Name":["Ajay","Rajat","Gaurav","Akash"],
    "Section":['A','B','C','D']
}

# %%
df = pd.DataFrame(a)
df
# Out:
#    ID    Name Section
# 0   1    Ajay       A
# 1   2   Rajat       B
# 2   3  Gaurav       C
# 3   4   Akash       D

# %%
df.to_csv("/content/sample_data.csv")

# %%
pd.read_csv("/content/sample_data.csv")
# Out:
#    Unnamed: 0  ID    Name Section
# 0           0   1    Ajay       A
# 1           1   2   Rajat       B
# 2           2   3  Gaurav       C
# 3           3   4   Akash       D

# %%
df = pd.read_csv("/content/placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head(6)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1
# 5  8.77          6.19       1

# %%
df.tail(6)
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.loc[1:6,['cgpa','placed']]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1
# 4  7.52       1
# 5  8.77       1
# 6  5.34       0

# %%
df.iloc[1:6,0:3]
# Out:
#    cgpa  resume_score  placed
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1
# 5  8.77          6.19       1

# %%
df.loc[4:5,['cgpa']]=1.33

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   1.33          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df.empty
b
# Out:
# False

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna()
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   1.33          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
i = df.ndim
i
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
t = df.shape
t
# Out:
# (100, 3)

# %%
d = df.size
d
# Out:
# 300

# %%
a = df.values
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [1.33, 7.3 , 1.  ],
#        [1.33, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df2 = df.copy()

# %%
p = df.sort_values(by = 'resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      1          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     20          6.52       1
# 1     18          5.17       0
# 2     20          8.86       1
# 3     18          7.27       1
# 4     16          7.30       1
# ..   ...           ...     ...
# 95    18          6.38       0
# 96    20          7.76       1
# 97    18          7.78       0
# 98    20          5.63       1
# 99    18          6.61       0
#
# [100 rows x 3 columns]

# %%
s = df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p = df.max()
p
# Out:
# cgpa            17.00
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
q = df.min()
q
# Out:
# cgpa            8.00
# resume_score    4.95
# placed          0.00
# dtype: float64

# %%
r = df['cgpa'].mean()
r
# Out:
# 14.33

# %%
s = df['cgpa'].median()
s
# Out:
# 14.0

# %%
s = df.sum()
s
# Out:
# cgpa            1433.00
# resume_score     693.05
# placed            50.00
# dtype: float64

# %%
g = df.filter(items = ['cgpa','placed'])
g
# Out:
#     cgpa  placed
# 0     20       1
# 1     18       0
# 2     20       1
# 3     18       1
# 4     16       1
# ..   ...     ...
# 95    18       0
# 96    20       1
# 97    18       0
# 98    20       1
# 99    18       0
#
# [100 rows x 2 columns]

# %%
df[['cgpa','placed']]
# Out:
#     cgpa  placed
# 0     20       1
# 1     18       0
# 2     20       1
# 3     18       1
# 4     16       1
# ..   ...     ...
# 95    18       0
# 96    20       1
# 97    18       0
# 98    20       1
# 99    18       0
#
# [100 rows x 2 columns]

# %%
s = df.filter(items = [5,6], axis =0)
s
# Out:
#    cgpa  resume_score  placed
# 5    13          6.19       1
# 6    17          7.09       0

# %%
p = df.rename(columns ={'cgpa':'updated_cgpa',
                        'resume_score':'semester_marks'})
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             20            6.52       1
# 1             18            5.17       0
# 2             20            8.86       1
# 3             18            7.27       1
# 4             16            7.30       1
# ..           ...             ...     ...
# 95            18            6.38       0
# 96            20            7.76       1
# 97            18            7.78       0
# 98            20            5.63       1
# 99            18            6.61       0
#
# [100 rows x 3 columns]

# %%
df['half'] = df['cgpa'].where(df['cgpa']>18,other = 0)
df.head(7)
# Out:
#    cgpa  resume_score  placed  half
# 0    20          6.52       1    20
# 1    18          5.17       0     0
# 2    20          8.86       1    20
# 3    18          7.27       1     0
# 4    16          7.30       1     0
# 5    13          6.19       1     0
# 6    17          7.09       0     0

# %%
# Parts of EDA
# 1) Univariate Analysis ==> Analysis on a single independent column_stack
# 2) Bivariate Analysis ==> Analysis on two column_stack
# 3) Multivariate Analysis ==> Analysis on more than 2 columns

# %%
# Data type
# 1 Numerical Data ==> Continuous Data ==> Age(year,month,days),height,weight
# 2 Categorical Data ==> descrete data ==> total number of employess

# %%
import matplotlib.pyplot as plt # Visualization Library
import seaborn as sns # Matplotlib's update version is seaborn

# %%
df = pd.read_csv("/content/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#Univariate Analysis

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.countplot(x = df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind ='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind ='pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Pclass'].value_counts().plot(kind = 'pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>
